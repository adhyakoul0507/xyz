# %%
import pandas as pd
import numpy as np

r = 102317026
ar = 0.05 * (r % 7)
br = 0.3 * ((r % 5) + 1)

df = pd.read_csv("data-3.csv", encoding="latin1", low_memory=False)
no2 = [c for c in df.columns if 'NO2' in c.upper()][0]
ok= pd.to_numeric(df[no2], errors='coerce')
ok= ok.dropna().values
tr = ok / np.max(np.abs(ok))


z = tr + ar * np.arcsin(br * tr)


mean = np.mean(ok2)
variance = np.var(ok2)
lamda = 1 / (2 * variance)
c = np.sqrt(lamda / np.pi)

print("mean =", mean)
print("lambda =", lamda)
print("c =", c)
# Out:
# mean = 0.029463039837684103
# lambda = 1120.7039391836472
# constant = 18.887327585639866
